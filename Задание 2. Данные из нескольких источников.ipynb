# %%
'''
Задание 2. Данные из нескольких источников
Получите данные по безработице в Москве:
https://video.ittensive.com/python-advanced/data-9753-2019-07-25.utf.csv
Объедините эти данные индексами (Месяц/Год) с данными из предыдущего задания (вызовы пожарных) 
для Центрального административного округа:
https://video.ittensive.com/python-advanced/data-5283-2019-10-04.utf.csv
Найдите значение поля UnemployedMen в том месяце, когда было меньше всего вызовов в Центральном административном округе.
'''

import pandas as pd # Импортирование библиотеки Pandas
data_1 = pd.read_csv("https://video.ittensive.com/python-advanced/data-9753-2019-07-25.utf.csv", delimiter=";")
# Загрузка csv-файла и разделение столбцов по ";" в строках CSV-файла
print (data_1) # вывод данных Pandas из переменной data_1
print ("----------------------------------------------------------------------------------------------------------------")
# Вывод разделяющей строки для лучшего восприятия данных
data_2 = pd.read_csv("https://video.ittensive.com/python-advanced/data-5283-2019-10-04.utf.csv", delimiter=";")
# Загрузка csv-файла и разделение столбцов по ";" в строке CSV-файла
print (data_2) # Вывод данных Pandas из переменной data_2
print ("----------------------------------------------------------------------------------------------------------------")
# Вывод разделяющей строки для лучшего восприятия данных
data_1 = data_1.set_index(["Year", "Period"]) # Установка мультииндекса столбцов для данных в data_1
data_2 = data_2.set_index(["AdmArea", "Year", "Month"]) 
# Установка мультииндекса столбцов для данных в data_2 для объединения данных
data_2 = data_2.loc["Центральный административный округ"] # loc - получение строк по метке
data_2.index.names = ["Year", "Period"] # Объявление имён индексов
data = pd.merge(data_1, data_2, left_index=True, right_index=True) # Объединение наборов данных по индексам 
data = data.reset_index() # Удаление (сброс) текущего индекса
data = data.set_index("Calls") # Назначение нового индекса по заданному столбцу 
data = data.sort_index() # Сортировка по индексу 
print () # Пропуск строки
print ("Значение поля 'UnemployedMen' в том месяце, когда было меньше всего вызовов в Центральном административном округе", "\n", data["UnemployedMen"].iloc[0:1])
# Извлечение первого значения заданного столбца после сортировки
# Out:
#      global_id   ID  Year  UnemployedMen  UnemployedWomen  UnemployedYoung  \
# 0     39809862    1  2001           8896            25762             6696
# 1     64592413    3  2003           8679            24967             6226
# 2     64592414    4  2004           9822            25239             7318
# 3     64592415    5  2005          10844            23597             6890
# 4     64592416    6  2006          11041            22928             6604
# ..         ...  ...   ...            ...              ...              ...
# 96   918869066  101  2019          13123            16904             3103
# 97   918869067  102  2019          13433            17164             3102
# 98   926094627  103  2019          13803            17319             3060
# 99   933200250  104  2019          12818            16221             2711
# 100  933200260  105  2019          12260            15769             2545
#
#      UnemployedDisabled  UnemployedTotal   Period  Unnamed: 9
# ...
